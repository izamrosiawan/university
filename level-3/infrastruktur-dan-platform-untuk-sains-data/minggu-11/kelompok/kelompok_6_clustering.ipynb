# %% [markdown]
# ## KELOMPOK 6 - DEVISVE CLUSTERING

# %% [markdown]
# Permasalahan utama yang ingin dipecahkan adalah mengidentifikasi dan mengelompokkan pola transaksi yang beragam dalam dataset penjualan.kami menerapkan metode Divisive Clustering (Top-Down).
#
#
# Diharapkan hasil ini memberikan profil statistik yang jelas dan terpisah, memungkinkan identifikasi kelompok transaksi dengan karakteristik unik.

# %% [markdown]
# ## **Divisive Clustering (Top-Down):**
#
# • Memulai dengan satu klaster yang berisi semua titik data.
#
# • Secara bertahap memisahkan klaster menjadi klaster yang lebih kecil.

# %% [markdown]
# Langkah-langkah:
#
# 1. Load data
#
# 2. Mengecek Tipe Data & Missing Value
#
# 3. Preprocessing
#
# 4. Split awal (1 → 2 klaster)
#
# 5. Split lanjutan (pilih klaster terbesar → pecah lagi)
#
# 6. Visualisasi
#
# 7. Evaluasi (SSE & Silhouette)

# %% [markdown]
# ---

# %%
# Library Import
import os
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.metrics import silhouette_score

# %%
# Membaca dataset
df = pd.read_csv('/content/data_penjualan.csv', delimiter=';')

df.head()
# Out:
#       Tanggal      Jenis Produk  Jumlah Order  Harga    Total
# 0  05/08/2022        Foodpak260          1000   1800  1800000
# 1  05/08/2022   FoodpakMatte245          1000   1900  1900000
# 2  05/08/2022  CraftLaminasi290          5000    750  3750000
# 3  05/08/2022  CraftLaminasi290          1000   1200  1200000
# 4  07/08/2022        Dupleks310          1000   1550  1550000

# %%
# Mengecek Tipe Data dan Missing Value
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tanggal       1076 non-null   object
#  1   Jenis Produk  1076 non-null   object
#  2   Jumlah Order  1076 non-null   int64
#  3   Harga         1076 non-null   int64
#  4   Total         1076 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 42.2+ KB
# Tanggal         0
# Jenis Produk    0
# Jumlah Order    0
# Harga           0
# Total           0
# dtype: int64

# %%
# PREPROCESSING – hanya pakai fitur numerik (Divisive clustering hanya bisa memproses data numerik)

# Pilih kolom numerik untuk clustering
features = ['Jumlah Order', 'Harga', 'Total']
X = df[features].copy()
X.head()
# Out:
#    Jumlah Order  Harga    Total
# 0          1000   1800  1800000
# 1          1000   1900  1900000
# 2          5000    750  3750000
# 3          1000   1200  1200000
# 4          1000   1550  1550000

# %%
# Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=features)

# %%
#PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_scaled)

# %%
#MENENTUKAN K OPTIMAL
wcss = []
for k in range(1, 10):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(pca_data)
    wcss.append(km.inertia_)

plt.plot(range(1,10), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("k")
plt.ylabel("WCSS")
plt.show()

# %%
from sklearn.metrics import silhouette_score

print("\nMENCARI NILAI k TERBAIK")

for k in range(2, 7):
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(pca_data)

    sil = silhouette_score(pca_data, labels)
    sse = km.inertia_

    print(f"k={k} | Silhouette={sil:.4f} | SSE={sse:.4f}")
# Out:
# MENCARI NILAI k TERBAIK
# k=2 | Silhouette=0.8072 | SSE=2105.2482
# k=3 | Silhouette=0.7129 | SSE=941.6690
# k=4 | Silhouette=0.5893 | SSE=603.8638
# k=5 | Silhouette=0.5315 | SSE=436.4757
# k=6 | Silhouette=0.5548 | SSE=301.8037

# %%
# DIVISIVE CLUSTERING SEDERHANA
# Tahap 1: Pisahkan data menjadi 2 cluster

# Awalnya semua data dianggap berada dalam 1 cluster besar
df["cluster"] = 0   # semua data = cluster 0

kmeans_1 = KMeans(n_clusters=2, random_state=42)
labels_2 = kmeans_1.fit_predict(X_scaled)

df["cluster"] = labels_2   # update dari cluster besar → 2 klaster

df["cluster"].value_counts()
# Out:
# cluster
# 0    972
# 1    104
# Name: count, dtype: int64

# %%
# Tahap 2: Pilih cluster yang terbesar → pecah lagi

# Ambil cluster yang ukurannya paling besar
largest_cluster = df["cluster"].value_counts().idxmax()

# Ambil data dari cluster tersebut
subset = X_scaled[df["cluster"] == largest_cluster]

# Split cluster besar menjadi 2 bagian
kmeans_split = KMeans(n_clusters=2, random_state=42)
split_labels = kmeans_split.fit_predict(subset)

# Map label split baru ke label global
new_label_id = df["cluster"].max() + 1

# Update cluster label pada dataframe
idx_subset = df[df["cluster"] == largest_cluster].index
df.loc[idx_subset[split_labels == 1], "cluster"] = new_label_id

df["cluster"].value_counts()
# Out:
# cluster
# 2    693
# 0    279
# 1    104
# Name: count, dtype: int64

# %%
# Menampilkan 10 baris pertama beserta label clusternya
print(df[["Jumlah Order", "Harga", "Total", "cluster"]].head(10))
# Out:
#    Jumlah Order  Harga    Total  cluster
# 0          1000   1800  1800000        2
# 1          1000   1900  1900000        2
# 2          5000    750  3750000        1
# 3          1000   1200  1200000        2
# 4          1000   1550  1550000        2
# 5           500   1900   950000        2
# 6          1000   1700  1700000        2
# 7          1000   1000  1000000        2
# 8          1500    850  1275000        2
# 9           500   1800   900000        2

# %% [markdown]
# Justifikasi $k=3$: Pemecahan ini dianggap sebagai yang paling "stabil" dan menghasilkan tiga kelompok transaksi (Klaster 0, Klaster 1, Klaster 2). Kelompok yang lebih kecil yang terbentuk setelah ini (misalnya, menjadi $k=4$ atau $k=5$) tidak lagi memiliki perbedaan jarak yang signifikan; mereka hanya memecah klaster yang sudah cukup mirip.

# %%
# EVALUASI

# SSE per cluster
def sse(X, labels):
    sse_total = 0
    for k in np.unique(labels):
        group = X[labels==k]
        centroid = group.mean(axis=0)
        sse_total += ((group - centroid)**2).sum()
    return sse_total

total_sse = sse(X_scaled, df["cluster"].values)
silhouette = silhouette_score(X_scaled, df["cluster"].values)

print("SSE:", total_sse)
print("Silhouette Score:", silhouette)
# Out:
# SSE: 1945.623837612074
# Silhouette Score: 0.46421257915948627

# %% [markdown]
# Hasil Evaluasi :
#
# - Nilai SSE kami adalah 1945.62. Nilai ini menunjukkan bahwa penyebaran data dalam klaster tergolong cukup rapat, dan pemisahan klaster yang terbentuk stabil meskipun tidak sepenuhnya optimal.
#
# - Silhouette Score kami sebesar 0.464 menunjukkan bahwa kualitas klaster yang terbentuk sudah cukup baik. Data dalam satu klaster cenderung mirip satu sama lain dan cukup terpisah dari klaster lainnya. Namun, masih terdapat sebagian data yang berada dekat dengan batas antar klaster.

# %%
# 7. VISUALISASI

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(8,6))
for k in df["cluster"].unique():
    plt.scatter(
        X_pca[df["cluster"]==k, 0],
        X_pca[df["cluster"]==k, 1],
        label=f"Cluster {k}",
        alpha=0.7
    )

plt.title("Divisive Clustering (Top-Down) – PCA 2D")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
plt.grid(True)
plt.show()

# %%
# BOXPLOT PER CLUSTER
for col in features:
  plt.figure(figsize=(8, 6))
  sns.boxplot(x=df["cluster"], y=df[col], hue=df["cluster"], palette="Set2", legend=False)
  plt.title(f"Boxplot {col} per Cluster", fontsize=14)
  plt.xlabel("Cluster", fontsize=12)
  plt.ylabel(col, fontsize=12)
  plt.show()

# %%
# HEATMAP KORELASI
corr = df[features].corr()
plt.figure(figsize=(6, 4))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Heatmap Korelasi Antar Fitur")
plt.show()

# %%
# HEATMAP PER CLUSTER
unique_clusters = df["cluster"].unique()

for cl in unique_clusters:
    plt.figure(figsize=(6, 4))
    subset_corr = df[df["cluster"] == cl][features].corr()
    sns.heatmap(subset_corr, annot=True, vmin=-1, vmax=1, cmap="coolwarm")
    plt.title(f"Heatmap Fitur Cluster {cl}")
    plt.show()

# %%
# PERHITUNGAN LINKAGE & PLOT DENDROGRAM

# Menghitung Matriks Linkage (Z)
# Menggunakan metode 'ward' yang umumnya direkomendasikan untuk menghasilkan klaster kompak.
Z = sch.linkage(X_scaled, method='ward')

# Plot Dendrogram
plt.figure(figsize=(14, 8))
odendro = sch.dendrogram(Z,
                    truncate_mode='lastp', # Menampilkan hanya 15 klaster terakhir untuk keterbacaan
                    p=15,
                    leaf_rotation=90.,
                    leaf_font_size=12.,
                    show_contracted=True)

plt.title('Dendrogram: Justifikasi Jumlah Klaster (k)', fontsize=16)
plt.xlabel('Indeks Sampel (atau Ukuran Klaster)', fontsize=12)
plt.ylabel('Jarak Euclidean (Dissimilarity)', fontsize=12)
plt.show()

# %% [markdown]
# - cluster 0 (Produk Unggulan(Premium))
# - cluster 1 (Produk Utama(Volume Tinggi))
# - cluster 2 (Produk Niche(Rendah))

# %%
# Tentukan threshold cut-off (cari dari dendrogram)
threshold = 15

plt.figure(figsize=(14, 8))
sch.dendrogram(
    Z,
    truncate_mode='lastp',
    p=15,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    color_threshold=threshold
)

# Garis horizontal cut-off
plt.axhline(y=threshold, color='red', linestyle='--', linewidth=2)

plt.title('Dendrogram dengan Cut-Off untuk K=3')
plt.xlabel('Indeks Sampel (atau Ukuran Klaster)')
plt.ylabel('Jarak Euclidean (Dissimilarity)')
plt.show()

# %% [markdown]
# yang kurang :
#
# - menentukan nilai k terbaik atau optimal
# - cara mengclusterkan dengan jarak
# - ditambahkan box plot antar per cluster hasil (0,1,2) dengan karakteristik awal
# - di pca lalu di clustering kan
