# %% [markdown]
# # Final Notebook — Analisis African Crises (Opsi A)
#
# Notebook ini berisi: forecasting inflasi, supervised banking-crisis classifier, dan klasterisasi. Data harus tersedia di `/mnt/data/african_crises.csv`.

# %%
# (Notebook content: preprocessing, forecasting, modeling, clustering)
print('Run the notebook cells to execute the full analysis.')
