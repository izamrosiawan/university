# %%
# 1. Buat sebuah list berisi nama-nama buah
buah = ["apel", "jeruk", "mangga"]
print(f"Isi list awal: {buah}")

# 2. Tambahkan buah baru di akhir
buah.append("pisang")
print(f"Setelah ditambah: {buah}")

# 3. Ambil buah di posisi kedua (indeks 1)
print(f"Buah kedua adalah: {buah[1]}")

# 4. Hapus 'jeruk' dari list
buah.remove("jeruk")
print(f"Setelah 'jeruk' dihapus: {buah}")

# 5. Cek ada berapa buah sekarang
print(f"Jumlah buah sekarang: {len(buah)}")
# Out:
# Isi list awal: ['apel', 'jeruk', 'mangga']
# Setelah ditambah: ['apel', 'jeruk', 'mangga', 'pisang']
# Buah kedua adalah: jeruk
# Setelah 'jeruk' dihapus: ['apel', 'mangga', 'pisang']
# Jumlah buah sekarang: 3

# %%
# 1. Buat dictionary data diri
mahasiswa = {"nama": "Budi", "nim": "12345", "kota": "Surabaya"}
print(f"Data awal: {mahasiswa}")

# 2. Ambil nama mahasiswa
print(f"Nama: {mahasiswa['nama']}")

# 3. Tambahkan data baru (jurusan)
mahasiswa["jurusan"] = "Data Sains"
print(f"Setelah ditambah jurusan: {mahasiswa}")

# 4. Ubah kota asal
mahasiswa["kota"] = "Jakarta"
print(f"Setelah diubah kotanya: {mahasiswa}")
# Out:
# Data awal: {'nama': 'Budi', 'nim': '12345', 'kota': 'Surabaya'}
# Nama: Budi
# Setelah ditambah jurusan: {'nama': 'Budi', 'nim': '12345', 'kota': 'Surabaya', 'jurusan': 'Data Sains'}
# Setelah diubah kotanya: {'nama': 'Budi', 'nim': '12345', 'kota': 'Jakarta', 'jurusan': 'Data Sains'}

# %%
penjualan = [120, 180, 90, 200, 160]
print("Total:", sum(penjualan))
print("Rata-rata:", sum(penjualan)/len(penjualan))
print("Maksimum:", max(penjualan))
# Out:
# Total: 750
# Rata-rata: 150.0
# Maksimum: 200

# %%
import matplotlib.pyplot as plt

plt.plot(data['tanggal'], data['jumlah'], marker='o')
plt.title('Grafik Penjualan per Tanggal')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah')
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array(range(len(data))).reshape(-1,1)  # misal prediksi berdasarkan urutan hari
y = data['jumlah'].values
model = LinearRegression()
model.fit(X, y)

# Prediksi penjualan hari ke-6
prediksi_hari6 = model.predict([[5]])
print("Prediksi penjualan hari ke-6:", int(prediksi_hari6[0]))
# Out:
# Prediksi penjualan hari ke-6: 126

# %%
print("absen")
# Out:
# absen

# %%
print("absen")
# Out:
# absen

# %%
print("absen")
# Out:
# absen

# %%
print("absen")
# Out:
# absen
